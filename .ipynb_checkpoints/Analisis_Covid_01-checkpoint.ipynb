# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
#Extracción de CSV de sitio de la onu
data = pd.read_csv('https://covid19.who.int/WHO-COVID-19-global-data.csv', 
                   parse_dates=['Date_reported'])

# %%
#Trim de etiquetas de columna ... issue del CSV de origen.
dic={}
for col in data.columns.values.tolist():
    dic[col]=col.strip()
data.rename(columns=dic, inplace=True)
data = data[['Date_reported', 
             'Country_code', 
             'Country', 
             'New_cases', 
             'New_deaths']]

# %%
#Agrupar paises y definir la fecha del día uno
data_country = data[['Country','Country_code','Date_reported']].groupby(['Country','Country_code']).min()
data_country.reset_index(inplace=True)
data_country.rename(columns={'Date_reported':'Date_one'}, inplace=True)

# %%
#Crea calendario basico en base a las fechas minima y maxima de la data completa
cal_start = data['Date_reported'].min()
cal_end = data['Date_reported'].max()

l_date=[]
l_n=[]
l_country=[]
l_country_code=[]
l_n_ep=[]
for i in range(0, data_country.shape[0]):
    n=0
    d=cal_start
    while d < cal_end:
        d=cal_start + dt.timedelta(days=n)
        n+=1
        l_country.append(data_country['Country'].tolist()[i])
        l_country_code.append(data_country['Country_code'].tolist()[i])
        l_date.append(d)
        l_n.append(n)
        diff = d - data_country['Date_one'].tolist()[i]
        diff = diff.days+1
        if diff<1:
            diff=0
        l_n_ep.append(diff)
        
calendar=pd.DataFrame({'Country':l_country, 
                       'Country_code':l_country_code, 
                       'Date':l_date, 
                       'Pandemic_day':l_n, 
                       'Epidemic_day':l_n_ep})

# %%
data.drop('Country_code', axis=1, inplace=True)
data_final = calendar.merge(data, how='left', left_on=['Country','Date'], right_on=['Country','Date_reported'])
data_final.drop('Date_reported', axis=1, inplace=True)
data_final['New_deaths'].fillna(0,inplace=True)
data_final['New_cases'].fillna(0,inplace=True)

# %%
data_final
# Out:
#                                                  Country Country_code  \
# 0                                            Afghanistan           AF
# 1                                            Afghanistan           AF
# 2                                            Afghanistan           AF
# 3                                            Afghanistan           AF
# 4                                            Afghanistan           AF
# ...                                                  ...          ...
# 51595  occupied Palestinian territory, including east...           PS
# 51596  occupied Palestinian territory, including east...           PS
# 51597  occupied Palestinian territory, including east...           PS
# 51598  occupied Palestinian territory, including east...           PS
# 51599  occupied Palestinian territory, including east...           PS
#
#             Date  Pandemic_day  Epidemic_day  New_cases  New_deaths
# 0     2020-01-04             1             0        0.0         0.0
# 1     2020-01-05             2             0        0.0         0.0
# 2     2020-01-06             3             0        0.0         0.0
# 3     2020-01-07             4             0        0.0         0.0
# 4     2020-01-08             5             0        0.0         0.0
# ...          ...           ...           ...        ...         ...
# 51595 2020-08-26           236           175      585.0         0.0
# 51596 2020-08-27           237           176      602.0         2.0
# 51597 2020-08-28           238           177      622.0         6.0
# 51598 2020-08-29           239           178      724.0         2.0
# 51599 2020-08-30           240           179      417.0         4.0
#
# [51600 rows x 7 columns]

# %%
ax=plt.gca()
data_final[(data_final['Country']=='Chile')].plot(kind='line', label='Chile', x='Epidemic_day',y='New_cases',ax=ax, color='red')
data_final[(data_final['Country']=='Germany')].plot(kind='line', label='Colombia', x='Epidemic_day',y='New_cases',ax=ax, color='blue')
#data_final.plot(kind='line',x='Pandemic_day',y='num_pets', color='red', ax=ax)
plt.show()

# %% [markdown]
# # Replanteo

# %%
#Extracción de CSV de sitio de la onu
data = pd.read_csv('https://covid19.who.int/WHO-COVID-19-global-data.csv', 
                   parse_dates=['Date_reported'])

# %%
#Trim de etiquetas de columna ... issue del CSV de origen.
dic={}
for col in data.columns.values.tolist():
    dic[col]=col.strip()
data.rename(columns=dic, inplace=True)
data = data[['Date_reported',
             'Country', 
             'New_cases', 
             'New_deaths']]

# %%
df = data.groupby('Country').apply(lambda x: x.set_index('Date_reported').resample('1D').first())

# %%
df1 = df.groupby(level=0)['New_cases'].apply(lambda x: x.shift().rolling(window=14).mean()).reset_index(name='s_New_cases')
df2 = df.groupby(level=0)['New_deaths'].apply(lambda x: x.shift().rolling(window=14).mean()).reset_index(name='s_New_deaths')

# %%
dff = df1.merge(df2,how='left',on=['Country','Date_reported'])

# %%
dff.dropna(inplace=True)

# %%
dff_d = dff[['Country','Date_reported']].groupby('Country').min()

# %%
dff_d.reset_index(inplace=True)

# %%
dff=dff.merge(dff_d,how='left',on='Country',suffixes=('','_a'))

# %%
dff['Epidemic_day']=(dff['Date_reported']-dff['Date_reported_a']).dt.days + 1

# %%
dff['Date_reported_b']=dff['Date_reported'].min()

# %%
dff['Pandemic_day']=(dff['Date_reported']-dff['Date_reported_b']).dt.days + 1

# %%
dff
# Out:
#                                                  Country Date_reported  \
# 0                                            Afghanistan    2020-03-09
# 1                                            Afghanistan    2020-03-10
# 2                                            Afghanistan    2020-03-11
# 3                                            Afghanistan    2020-03-12
# 4                                            Afghanistan    2020-03-13
# ...                                                  ...           ...
# 35324  occupied Palestinian territory, including east...    2020-08-26
# 35325  occupied Palestinian territory, including east...    2020-08-27
# 35326  occupied Palestinian territory, including east...    2020-08-28
# 35327  occupied Palestinian territory, including east...    2020-08-29
# 35328  occupied Palestinian territory, including east...    2020-08-30
#
#        s_New_cases  s_New_deaths Date_reported_a  Epidemic_day  \
# 0         0.571429      0.000000      2020-03-09             1
# 1         0.214286      0.000000      2020-03-09             2
# 2         0.214286      0.000000      2020-03-09             3
# 3         0.428571      0.000000      2020-03-09             4
# 4         0.428571      0.000000      2020-03-09             5
# ...            ...           ...             ...           ...
# 35324   461.142857      2.857143      2020-03-19           161
# 35325   469.142857      2.571429      2020-03-19           162
# 35326   476.500000      2.642857      2020-03-19           163
# 35327   490.071429      3.000000      2020-03-19           164
# 35328   503.857143      3.142857      2020-03-19           165
#
#       Date_reported_b  Pandemic_day
# 0          2020-01-18            52
# 1          2020-01-18            53
# 2          2020-01-18            54
# 3          2020-01-18            55
# 4          2020-01-18            56
# ...               ...           ...
# 35324      2020-01-18           222
# 35325      2020-01-18           223
# 35326      2020-01-18           224
# 35327      2020-01-18           225
# 35328      2020-01-18           226
#
# [35329 rows x 8 columns]

# %%
data_final=dff[['Country','Date_reported','Pandemic_day','Epidemic_day','s_New_cases','s_New_deaths']]

# %%
data_final
# Out:
#                                                  Country Date_reported  \
# 0                                            Afghanistan    2020-03-09
# 1                                            Afghanistan    2020-03-10
# 2                                            Afghanistan    2020-03-11
# 3                                            Afghanistan    2020-03-12
# 4                                            Afghanistan    2020-03-13
# ...                                                  ...           ...
# 35324  occupied Palestinian territory, including east...    2020-08-26
# 35325  occupied Palestinian territory, including east...    2020-08-27
# 35326  occupied Palestinian territory, including east...    2020-08-28
# 35327  occupied Palestinian territory, including east...    2020-08-29
# 35328  occupied Palestinian territory, including east...    2020-08-30
#
#        Pandemic_day  Epidemic_day  s_New_cases  s_New_deaths
# 0                52             1     0.571429      0.000000
# 1                53             2     0.214286      0.000000
# 2                54             3     0.214286      0.000000
# 3                55             4     0.428571      0.000000
# 4                56             5     0.428571      0.000000
# ...             ...           ...          ...           ...
# 35324           222           161   461.142857      2.857143
# 35325           223           162   469.142857      2.571429
# 35326           224           163   476.500000      2.642857
# 35327           225           164   490.071429      3.000000
# 35328           226           165   503.857143      3.142857
#
# [35329 rows x 6 columns]

# %%
ax=plt.gca()
data_final[(data_final['Country']=='Chile')].plot(kind='line', label='Chile', x='Epidemic_day',y='s_New_cases',ax=ax, color='red')
data_final[(data_final['Country']=='Germany')].plot(kind='line', label='Germany', x='Epidemic_day',y='s_New_cases',ax=ax, color='blue')
#data_final.plot(kind='line',x='Pandemic_day',y='num_pets', color='red', ax=ax)
plt.show()
